# %% [markdown]
# ### 1.1 Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_parquet('dataset.parquet')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442961 entries, 0 to 442960
# Data columns (total 78 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   borrow_block_number                      442961 non-null  int64
#  1   borrow_timestamp                         442961 non-null  float64
#  2   wallet_address                           442961 non-null  object
#  3   first_tx_timestamp                       442961 non-null  float64
#  4   last_tx_timestamp                        442961 non-null  float64
#  5   wallet_age                               442961 non-null  float64
#  6   incoming_tx_count                        442961 non-null  int64
#  7   outgoing_tx_count                        442961 non-null  int64
#  8   net_incoming_tx_count                    442961 non-null  int64
#  9   total_gas_paid_eth                       442961 non-null  float64
#  10  avg_gas_paid_per_tx_eth                  442961 non-null  float64
#  11  risky_tx_count                           442961 non-null  int64
#  12  risky_unique_contract_count              442961 non-null  int64
#  13  risky_first_tx_timestamp                 442961 non-null  int64
#  14  risky_last_tx_timestamp                  442961 non-null  int64
#  15  risky_first_last_tx_timestamp_diff       442961 non-null  int64
#  16  risky_sum_outgoing_amount_eth            442961 non-null  float64
#  17  outgoing_tx_sum_eth                      442961 non-null  float64
#  18  incoming_tx_sum_eth                      442961 non-null  float64
#  19  outgoing_tx_avg_eth                      442961 non-null  float64
#  20  incoming_tx_avg_eth                      442961 non-null  float64
#  21  max_eth_ever                             442961 non-null  float64
#  22  min_eth_ever                             442961 non-null  float64
#  23  total_balance_eth                        442961 non-null  float64
#  24  risk_factor                              442961 non-null  float64
#  25  total_collateral_eth                     442961 non-null  float64
#  26  total_collateral_avg_eth                 442961 non-null  float64
#  27  total_available_borrows_eth              442961 non-null  float64
#  28  total_available_borrows_avg_eth          442961 non-null  float64
#  29  avg_weighted_risk_factor                 442961 non-null  float64
#  30  risk_factor_above_threshold_daily_count  442961 non-null  float64
#  31  avg_risk_factor                          442961 non-null  float64
#  32  max_risk_factor                          442961 non-null  float64
#  33  borrow_amount_sum_eth                    442961 non-null  float64
#  34  borrow_amount_avg_eth                    442961 non-null  float64
#  35  borrow_count                             442961 non-null  int64
#  36  repay_amount_sum_eth                     442961 non-null  float64
#  37  repay_amount_avg_eth                     442961 non-null  float64
#  38  repay_count                              442961 non-null  int64
#  39  borrow_repay_diff_eth                    442961 non-null  float64
#  40  deposit_count                            442961 non-null  int64
#  41  deposit_amount_sum_eth                   442961 non-null  float64
#  42  time_since_first_deposit                 442961 non-null  float64
#  43  withdraw_amount_sum_eth                  442961 non-null  float64
#  44  withdraw_deposit_diff_if_positive_eth    442961 non-null  float64
#  45  liquidation_count                        442961 non-null  int64
#  46  time_since_last_liquidated               442961 non-null  float64
#  47  liquidation_amount_sum_eth               442961 non-null  float64
#  48  market_adx                               442961 non-null  float64
#  49  market_adxr                              442961 non-null  float64
#  50  market_apo                               442961 non-null  float64
#  51  market_aroonosc                          442961 non-null  float64
#  52  market_aroonup                           442961 non-null  float64
#  53  market_atr                               442961 non-null  float64
#  54  market_cci                               442961 non-null  float64
#  55  market_cmo                               442961 non-null  float64
#  56  market_correl                            442961 non-null  float64
#  57  market_dx                                442961 non-null  float64
#  58  market_fastk                             442961 non-null  float64
#  59  market_fastd                             442961 non-null  float64
#  60  market_ht_trendmode                      442961 non-null  int64
#  61  market_linearreg_slope                   442961 non-null  float64
#  62  market_macd_macdext                      442961 non-null  float64
#  63  market_macd_macdfix                      442961 non-null  float64
#  64  market_macd                              442961 non-null  float64
#  65  market_macdsignal_macdext                442961 non-null  float64
#  66  market_macdsignal_macdfix                442961 non-null  float64
#  67  market_macdsignal                        442961 non-null  float64
#  68  market_max_drawdown_365d                 442961 non-null  float64
#  69  market_natr                              442961 non-null  float64
#  70  market_plus_di                           442961 non-null  float64
#  71  market_plus_dm                           442961 non-null  float64
#  72  market_ppo                               442961 non-null  float64
#  73  market_rocp                              442961 non-null  float64
#  74  market_rocr                              442961 non-null  float64
#  75  unique_borrow_protocol_count             442961 non-null  int64
#  76  unique_lending_protocol_count            442961 non-null  int64
#  77  target                                   442961 non-null  int64
# dtypes: float64(60), int64(17), object(1)
# memory usage: 263.6+ MB

# %%
# !conda update pandas pyarrow
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda/envs/example/lib/python3.10/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/core/frame.py:1136, in _repr_html_(self)
#    1133 arr = blocks[0].values
#    1134 if arr.ndim == 1:
#    1135     # non-2D ExtensionArray
# -> 1136     return self.values
#    1138 # more generally, whatever we allow in NDArrayBackedExtensionBlock
#    1139 arr = cast("np.ndarray | DatetimeArray | TimedeltaArray | PeriodArray", arr)
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/format.py:1108, in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1079 def format_array(
#    1080     values: ArrayLike,
#    1081     formatter: Callable | None,
#    (...)
#    1090     fallback_formatter: Callable | None = None,
#    1091 ) -> list[str]:
#    1092     """
#    1093     Format an array for printing.
#    1094
#    1095     Parameters
#    1096     ----------
#    1097     values : np.ndarray or ExtensionArray
#    1098     formatter
#    1099     float_format
#    1100     na_rep
#    1101     digits
#    1102     space
#    1103     justify
#    1104     decimal
#    1105     leading_space : bool, optional, default True
#    1106         Whether the array should be formatted with a leading space.
#    1107         When an array as a column of a Series or DataFrame, we do want
# -> 1108         the leading space to pad between columns.
#    1109
#    1110         When formatting an Index subclass
#    1111         (e.g. IntervalIndex._get_values_for_csv), we don't want the
#    1112         leading space since it should be left-aligned.
#    1113     fallback_formatter
#    1114
#    1115     Returns
#    1116     -------
#    1117     List[str]
#    1118     """
#    1119     fmt_klass: type[_GenericArrayFormatter]
#    1120     if lib.is_np_dtype(values.dtype, "M"):
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:644, in NotebookFormatter.render(self)
#     642 self.write("<div>")
#     643 self.write_style()
# --> 644 super().render()
#     645 self.write("</div>")
#     646 return self.elements
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:267, in HTMLFormatter._write_table(self, indent)
#     261 self.write(
#     262     f'<table{border_attr} class="{" ".join(_classes)}"{id_section}>',
#     263     indent,
#     264 )
#     266 if self.fmt.header or self.show_row_idx_names:
# --> 267     self._write_header(indent + self.indent_delta)
#     269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:403, in HTMLFormatter._write_header(self, indent)
#     400 self.write("<thead>", indent)
#     402 if self.fmt.header:
# --> 403     self._write_col_header(indent + self.indent_delta)
#     405 if self.show_row_idx_names:
#     406     self._write_row_header(indent + self.indent_delta)
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:383, in HTMLFormatter._write_col_header(self, indent)
#     381     else:
#     382         row.append("")
# --> 383 row.extend(self._get_columns_formatted_values())
#     384 align = self.fmt.justify
#     386 if is_truncated_horizontally:
#
# File ~/miniconda/envs/example/lib/python3.10/site-packages/pandas/io/formats/html.py:611, in NotebookFormatter._get_columns_formatted_values(self)
#     609 def _get_columns_formatted_values(self) -> list[str]:
#     610     # only reached with non-Multi Index
# --> 611     return self.columns._format_flat(include_name=False)
#
# AttributeError: 'Index' object has no attribute '_format_flat'
#        borrow_block_number  borrow_timestamp  first_tx_timestamp  \
# count         4.429610e+05      4.429610e+05        4.429610e+05
# mean          1.304907e+07      1.629225e+09        1.593978e+09
# std           2.231888e+06      2.972367e+07        4.485955e+07
# min           7.711117e+06      1.557197e+09        1.438270e+09
# 25%           1.162464e+07      1.610250e+09        1.570976e+09
# 50%           1.270531e+07      1.624652e+09        1.601186e+09
# 75%           1.481634e+07      1.653123e+09        1.621893e+09
# max           1.825192e+07      1.696118e+09        1.696060e+09
#
#        last_tx_timestamp    wallet_age  incoming_tx_count  outgoing_tx_count  \
# count       4.429610e+05  4.429610e+05      442961.000000       4.429610e+05
# mean        1.629120e+09  3.524693e+07         777.858238       2.196224e+03
# std         2.970179e+07  3.828899e+07        2306.781076       2.803049e+04
# min         1.557197e+09  0.000000e+00           0.000000       0.000000e+00
# 25%         1.610199e+09  6.621387e+06          39.000000       5.800000e+01
# 50%         1.624549e+09  2.120514e+07         158.000000       2.480000e+02
# 75%         1.653021e+09  5.088168e+07         567.000000       9.210000e+02
# max         1.701649e+09  2.547487e+08      197999.000000       1.003714e+06
#
#        net_incoming_tx_count  total_gas_paid_eth  avg_gas_paid_per_tx_eth  \
# count          442961.000000       442961.000000            442961.000000
# mean            -1418.365727           26.898496                 0.015685
# std             27699.991076          141.471489                 0.030737
# min           -996456.000000            0.000000                 0.000000
# 25%              -273.000000            0.364798                 0.005112
# 50%               -62.000000            2.268351                 0.010691
# 75%                -9.000000           12.675138                 0.018049
# max            196374.000000         9951.709230                 2.586824
#
#        ...  market_max_drawdown_365d    market_natr  market_plus_di  \
# count  ...             442961.000000  442961.000000   442961.000000
# mean   ...                 -0.650871       6.102657       23.324148
# std    ...                  0.127519       2.281503        9.257275
# min    ...                 -0.992921       2.842363        4.674813
# 25%    ...                 -0.736622       4.393287       15.907632
# 50%    ...                 -0.668490       5.569394       22.166548
# 75%    ...                 -0.608560       7.284896       29.496384
# max    ...                 -0.361351      15.106064       56.729534
#
#        market_plus_dm     market_ppo    market_rocp    market_rocr  \
# count   442961.000000  442961.000000  442961.000000  442961.000000
# mean      1062.136487       2.020113       0.038512       1.038512
# std      21143.683448       8.304551       0.176627       0.176627
# min          5.413265     -29.248726      -0.545814       0.454186
# 25%        129.436901      -3.275724      -0.068142       0.931858
# 50%        333.246607       1.652219       0.023303       1.023303
# 75%        560.550257       7.337788       0.138449       1.138449
# max     807296.000000      28.435216       0.768294       1.768294
#
#        unique_borrow_protocol_count  unique_lending_protocol_count  \
# count                 442961.000000                  442961.000000
# mean                       0.975084                       1.223742
# std                        0.558809                       0.443834
# min                        0.000000                       0.000000
# 25%                        1.000000                       1.000000
# 50%                        1.000000                       1.000000
# 75%                        1.000000                       1.000000
# max                        4.000000                       2.000000
#
#               target
# count  442961.000000
# mean        0.375202
# std         0.484176
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 77 columns]
