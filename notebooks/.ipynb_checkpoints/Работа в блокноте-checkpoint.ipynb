# %% [markdown]
# ### 1.1 Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import pyarrow as pa
# from scipy.stats import randint
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, precision_recall_curve
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from model_evaluation import (
    evaluate_model, 
    confusion_matrix_graf, 
    roc_curves_graf, 
    precision_recall_curves_graf,
    #evaluate_all_metrics
)

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_parquet('../data/dataset.parquet')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442961 entries, 0 to 442960
# Data columns (total 78 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   borrow_block_number                      442961 non-null  int64
#  1   borrow_timestamp                         442961 non-null  float64
#  2   wallet_address                           442961 non-null  object
#  3   first_tx_timestamp                       442961 non-null  float64
#  4   last_tx_timestamp                        442961 non-null  float64
#  5   wallet_age                               442961 non-null  float64
#  6   incoming_tx_count                        442961 non-null  int64
#  7   outgoing_tx_count                        442961 non-null  int64
#  8   net_incoming_tx_count                    442961 non-null  int64
#  9   total_gas_paid_eth                       442961 non-null  float64
#  10  avg_gas_paid_per_tx_eth                  442961 non-null  float64
#  11  risky_tx_count                           442961 non-null  int64
#  12  risky_unique_contract_count              442961 non-null  int64
#  13  risky_first_tx_timestamp                 442961 non-null  int64
#  14  risky_last_tx_timestamp                  442961 non-null  int64
#  15  risky_first_last_tx_timestamp_diff       442961 non-null  int64
#  16  risky_sum_outgoing_amount_eth            442961 non-null  float64
#  17  outgoing_tx_sum_eth                      442961 non-null  float64
#  18  incoming_tx_sum_eth                      442961 non-null  float64
#  19  outgoing_tx_avg_eth                      442961 non-null  float64
#  20  incoming_tx_avg_eth                      442961 non-null  float64
#  21  max_eth_ever                             442961 non-null  float64
#  22  min_eth_ever                             442961 non-null  float64
#  23  total_balance_eth                        442961 non-null  float64
#  24  risk_factor                              442961 non-null  float64
#  25  total_collateral_eth                     442961 non-null  float64
#  26  total_collateral_avg_eth                 442961 non-null  float64
#  27  total_available_borrows_eth              442961 non-null  float64
#  28  total_available_borrows_avg_eth          442961 non-null  float64
#  29  avg_weighted_risk_factor                 442961 non-null  float64
#  30  risk_factor_above_threshold_daily_count  442961 non-null  float64
#  31  avg_risk_factor                          442961 non-null  float64
#  32  max_risk_factor                          442961 non-null  float64
#  33  borrow_amount_sum_eth                    442961 non-null  float64
#  34  borrow_amount_avg_eth                    442961 non-null  float64
#  35  borrow_count                             442961 non-null  int64
#  36  repay_amount_sum_eth                     442961 non-null  float64
#  37  repay_amount_avg_eth                     442961 non-null  float64
#  38  repay_count                              442961 non-null  int64
#  39  borrow_repay_diff_eth                    442961 non-null  float64
#  40  deposit_count                            442961 non-null  int64
#  41  deposit_amount_sum_eth                   442961 non-null  float64
#  42  time_since_first_deposit                 442961 non-null  float64
#  43  withdraw_amount_sum_eth                  442961 non-null  float64
#  44  withdraw_deposit_diff_if_positive_eth    442961 non-null  float64
#  45  liquidation_count                        442961 non-null  int64
#  46  time_since_last_liquidated               442961 non-null  float64
#  47  liquidation_amount_sum_eth               442961 non-null  float64
#  48  market_adx                               442961 non-null  float64
#  49  market_adxr                              442961 non-null  float64
#  50  market_apo                               442961 non-null  float64
#  51  market_aroonosc                          442961 non-null  float64
#  52  market_aroonup                           442961 non-null  float64
#  53  market_atr                               442961 non-null  float64
#  54  market_cci                               442961 non-null  float64
#  55  market_cmo                               442961 non-null  float64
#  56  market_correl                            442961 non-null  float64
#  57  market_dx                                442961 non-null  float64
#  58  market_fastk                             442961 non-null  float64
#  59  market_fastd                             442961 non-null  float64
#  60  market_ht_trendmode                      442961 non-null  int64
#  61  market_linearreg_slope                   442961 non-null  float64
#  62  market_macd_macdext                      442961 non-null  float64
#  63  market_macd_macdfix                      442961 non-null  float64
#  64  market_macd                              442961 non-null  float64
#  65  market_macdsignal_macdext                442961 non-null  float64
#  66  market_macdsignal_macdfix                442961 non-null  float64
#  67  market_macdsignal                        442961 non-null  float64
#  68  market_max_drawdown_365d                 442961 non-null  float64
#  69  market_natr                              442961 non-null  float64
#  70  market_plus_di                           442961 non-null  float64
#  71  market_plus_dm                           442961 non-null  float64
#  72  market_ppo                               442961 non-null  float64
#  73  market_rocp                              442961 non-null  float64
#  74  market_rocr                              442961 non-null  float64
#  75  unique_borrow_protocol_count             442961 non-null  int64
#  76  unique_lending_protocol_count            442961 non-null  int64
#  77  target                                   442961 non-null  int64
# dtypes: float64(60), int64(17), object(1)
# memory usage: 263.6+ MB

# %%
data.shape
# Out:
# (442961, 78)

# %%
data.columns
# Out:
# Index(['borrow_block_number', 'borrow_timestamp', 'wallet_address',
#        'first_tx_timestamp', 'last_tx_timestamp', 'wallet_age',
#        'incoming_tx_count', 'outgoing_tx_count', 'net_incoming_tx_count',
#        'total_gas_paid_eth', 'avg_gas_paid_per_tx_eth', 'risky_tx_count',
#        'risky_unique_contract_count', 'risky_first_tx_timestamp',
#        'risky_last_tx_timestamp', 'risky_first_last_tx_timestamp_diff',
#        'risky_sum_outgoing_amount_eth', 'outgoing_tx_sum_eth',
#        'incoming_tx_sum_eth', 'outgoing_tx_avg_eth', 'incoming_tx_avg_eth',
#        'max_eth_ever', 'min_eth_ever', 'total_balance_eth', 'risk_factor',
#        'total_collateral_eth', 'total_collateral_avg_eth',
#        'total_available_borrows_eth', 'total_available_borrows_avg_eth',
#        'avg_weighted_risk_factor', 'risk_factor_above_threshold_daily_count',
#        'avg_risk_factor', 'max_risk_factor', 'borrow_amount_sum_eth',
#        'borrow_amount_avg_eth', 'borrow_count', 'repay_amount_sum_eth',
#        'repay_amount_avg_eth', 'repay_count', 'borrow_repay_diff_eth',
#        'deposit_count', 'deposit_amount_sum_eth', 'time_since_first_deposit',
#        'withdraw_amount_sum_eth', 'withdraw_deposit_diff_if_positive_eth',
#        'liquidation_count', 'time_since_last_liquidated',
#        'liquidation_amount_sum_eth', 'market_adx', 'market_adxr', 'market_apo',
#        'market_aroonosc', 'market_aroonup', 'market_atr', 'market_cci',
#        'market_cmo', 'market_correl', 'market_dx', 'market_fastk',
#        'market_fastd', 'market_ht_trendmode', 'market_linearreg_slope',
#        'market_macd_macdext', 'market_macd_macdfix', 'market_macd',
#        'market_macdsignal_macdext', 'market_macdsignal_macdfix',
#        'market_macdsignal', 'market_max_drawdown_365d', 'market_natr',
#        'market_plus_di', 'market_plus_dm', 'market_ppo', 'market_rocp',
#        'market_rocr', 'unique_borrow_protocol_count',
#        'unique_lending_protocol_count', 'target'],
#       dtype='object')

# %%
data = data.drop('wallet_address', axis=1)

# %%
data.describe(include='float64')
# Out:
#        borrow_timestamp  first_tx_timestamp  last_tx_timestamp    wallet_age  \
# count      4.429610e+05        4.429610e+05       4.429610e+05  4.429610e+05
# mean       1.629225e+09        1.593978e+09       1.629120e+09  3.524693e+07
# std        2.972367e+07        4.485955e+07       2.970179e+07  3.828899e+07
# min        1.557197e+09        1.438270e+09       1.557197e+09  0.000000e+00
# 25%        1.610250e+09        1.570976e+09       1.610199e+09  6.621387e+06
# 50%        1.624652e+09        1.601186e+09       1.624549e+09  2.120514e+07
# 75%        1.653123e+09        1.621893e+09       1.653021e+09  5.088168e+07
# max        1.696118e+09        1.696060e+09       1.701649e+09  2.547487e+08
#
#        total_gas_paid_eth  avg_gas_paid_per_tx_eth  \
# count       442961.000000            442961.000000
# mean            26.898496                 0.015685
# std            141.471489                 0.030737
# min              0.000000                 0.000000
# 25%              0.364798                 0.005112
# 50%              2.268351                 0.010691
# 75%             12.675138                 0.018049
# max           9951.709230                 2.586824
#
#        risky_sum_outgoing_amount_eth  outgoing_tx_sum_eth  \
# count                   4.429610e+05         4.429610e+05
# mean                    2.312860e+04         1.071285e+05
# std                     2.230375e+05         7.097087e+05
# min                     0.000000e+00         0.000000e+00
# 25%                     0.000000e+00         6.151085e+01
# 50%                     4.382761e+01         7.793659e+02
# 75%                     8.957546e+02         8.697555e+03
# max                     1.294037e+07         2.021488e+07
#
#        incoming_tx_sum_eth  outgoing_tx_avg_eth  ...  \
# count         4.429610e+05        442961.000000  ...
# mean          1.030546e+05            31.891906  ...
# std           6.549361e+05           250.161534  ...
# min           0.000000e+00             0.000000  ...
# 25%           7.979699e+01             0.277378  ...
# 50%           8.290144e+02             1.531728  ...
# 75%           8.865910e+03             7.925058  ...
# max           2.014653e+07         30211.095748  ...
#
#        market_macdsignal_macdext  market_macdsignal_macdfix  \
# count              442961.000000              442961.000000
# mean                   25.942980                  22.369506
# std                   157.747496                 102.262312
# min                  -533.215038                -274.787793
# 25%                   -41.164218                 -25.716493
# 50%                    11.972290                   8.946516
# 75%                   104.865957                  83.314472
# max                   570.929181                 372.715172
#
#        market_macdsignal  market_max_drawdown_365d    market_natr  \
# count      442961.000000             442961.000000  442961.000000
# mean           23.478711                 -0.650871       6.102657
# std           107.338012                  0.127519       2.281503
# min          -288.690622                 -0.992921       2.842363
# 25%           -26.736740                 -0.736622       4.393287
# 50%             9.423609                 -0.668490       5.569394
# 75%            87.762008                 -0.608560       7.284896
# max           391.719370                 -0.361351      15.106064
#
#        market_plus_di  market_plus_dm     market_ppo    market_rocp  \
# count   442961.000000   442961.000000  442961.000000  442961.000000
# mean        23.324148     1062.136487       2.020113       0.038512
# std          9.257275    21143.683448       8.304551       0.176627
# min          4.674813        5.413265     -29.248726      -0.545814
# 25%         15.907632      129.436901      -3.275724      -0.068142
# 50%         22.166548      333.246607       1.652219       0.023303
# 75%         29.496384      560.550257       7.337788       0.138449
# max         56.729534   807296.000000      28.435216       0.768294
#
#          market_rocr
# count  442961.000000
# mean        1.038512
# std         0.176627
# min         0.454186
# 25%         0.931858
# 50%         1.023303
# 75%         1.138449
# max         1.768294
#
# [8 rows x 60 columns]

# %%
data.describe(include='int64')
# Out:
#        borrow_block_number  incoming_tx_count  outgoing_tx_count  \
# count         4.429610e+05      442961.000000       4.429610e+05
# mean          1.304907e+07         777.858238       2.196224e+03
# std           2.231888e+06        2306.781076       2.803049e+04
# min           7.711117e+06           0.000000       0.000000e+00
# 25%           1.162464e+07          39.000000       5.800000e+01
# 50%           1.270531e+07         158.000000       2.480000e+02
# 75%           1.481634e+07         567.000000       9.210000e+02
# max           1.825192e+07      197999.000000       1.003714e+06
#
#        net_incoming_tx_count  risky_tx_count  risky_unique_contract_count  \
# count          442961.000000   442961.000000                442961.000000
# mean            -1418.365727      118.291513                    18.720851
# std             27699.991076      314.279904                    35.596185
# min           -996456.000000        0.000000                     0.000000
# 25%              -273.000000        1.000000                     1.000000
# 50%               -62.000000       17.000000                     6.000000
# 75%                -9.000000       88.000000                    20.000000
# max            196374.000000    10364.000000                   843.000000
#
#        risky_first_tx_timestamp  risky_last_tx_timestamp  \
# count              4.429610e+05             4.429610e+05
# mean               1.483994e+09             1.497026e+09
# std                2.515203e+08             2.584733e+08
# min                1.000000e+09             1.000000e+09
# 25%                1.592219e+09             1.594498e+09
# 50%                1.600174e+09             1.618701e+09
# 75%                1.619090e+09             1.638324e+09
# max                1.696097e+09             1.696104e+09
#
#        risky_first_last_tx_timestamp_diff   borrow_count    repay_count  \
# count                        4.429610e+05  442961.000000  442961.000000
# mean                         1.303211e+07      60.942146      46.051842
# std                          1.759031e+07     202.519253     175.857355
# min                          0.000000e+00       0.000000       0.000000
# 25%                          0.000000e+00       2.000000       0.000000
# 50%                          5.400272e+06       9.000000       3.000000
# 75%                          1.997586e+07      37.000000      20.000000
# max                          1.040981e+08    7500.000000    6255.000000
#
#        deposit_count  liquidation_count  market_ht_trendmode  \
# count  442961.000000      442961.000000        442961.000000
# mean       72.793492           1.420249             0.925154
# std       318.035593          10.950239             0.263144
# min         0.000000           0.000000             0.000000
# 25%         3.000000           0.000000             1.000000
# 50%        11.000000           0.000000             1.000000
# 75%        41.000000           0.000000             1.000000
# max      8603.000000         204.000000             1.000000
#
#        unique_borrow_protocol_count  unique_lending_protocol_count  \
# count                 442961.000000                  442961.000000
# mean                       0.975084                       1.223742
# std                        0.558809                       0.443834
# min                        0.000000                       0.000000
# 25%                        1.000000                       1.000000
# 50%                        1.000000                       1.000000
# 75%                        1.000000                       1.000000
# max                        4.000000                       2.000000
#
#               target
# count  442961.000000
# mean        0.375202
# std         0.484176
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
time_columns = [
    'borrow_timestamp', 'first_tx_timestamp', 'last_tx_timestamp',
    'risky_first_tx_timestamp', 'risky_last_tx_timestamp'
]

# %%
df = data.copy()
for i in time_columns:
    if i in data.columns:
        df[i] = pd.to_datetime(data[i],unit='s')

# %%
df.describe(include='datetime64')
# Out:
#                     borrow_timestamp             first_tx_timestamp  \
# count                         442961                         442961
# mean   2021-08-17 18:22:11.321940224  2020-07-05 19:33:22.714699776
# min              2019-05-07 02:48:28            2015-07-30 15:26:13
# 25%              2021-01-10 03:33:34            2019-10-13 14:12:58
# 50%              2021-06-25 20:19:41            2020-09-27 06:00:15
# 75%              2022-05-21 08:55:35            2021-05-24 21:43:44
# max              2023-09-30 23:51:23            2023-09-30 07:53:35
#
#                    last_tx_timestamp       risky_first_tx_timestamp  \
# count                         442961                         442961
# mean   2021-08-16 13:14:20.570399488  2017-01-09 20:35:35.081645312
# min              2019-05-07 02:44:34            2001-09-09 01:46:39
# 25%              2021-01-09 13:24:00            2020-06-15 11:08:26
# 50%              2021-06-24 15:44:48            2020-09-15 12:43:10
# 75%              2022-05-20 04:26:50            2021-04-22 11:13:19
# max              2023-12-04 00:22:59            2023-09-30 17:58:59
#
#              risky_last_tx_timestamp
# count                         442961
# mean   2017-06-09 16:37:26.175311104
# min              2001-09-09 01:46:39
# 25%              2020-07-11 20:04:48
# 50%              2021-04-17 23:01:56
# 75%              2021-12-01 02:06:50
# max              2023-09-30 20:07:59

# %%
if 'target' in data.select_dtypes(include=['number']).columns:
    corr_with_target = data.select_dtypes(include=['number']).corr()['target'].abs().sort_values(ascending=False)
    top_columns = corr_with_target.head(20).index
    top_data = data.select_dtypes(include=['number'])[top_columns]
    
    plt.figure(figsize=(16, 14))
    sns.heatmap(top_data.corr(), annot=True, fmt='.2f', cmap='coolwarm', center=0)
    plt.title('Корреляция топ-20 признаков с target')
    plt.show()

# %%
X = data.drop('target',axis=1)
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)

# %%
numeric_cols = X.select_dtypes(include=[np.number]).columns
scaler = StandardScaler()
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()
X_train_scaled[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])
X_test_scaled[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=21, n_jobs=-1)

# %%
rfc.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=21)

# %%
results_df = pd.DataFrame()

# %%
results_df = evaluate_model(
    model=rfc,  # ваша обученная модель
    X_train=X_train_scaled,
    X_test=X_test_scaled, 
    y_train=y_train,
    y_test=y_test,
    model_name='Random Forest',
    results_df=results_df
)

# %%
results_df
# Out:
#            Model  Test_Accuracy  Test_Precision  Test_Recall   Test_F1  \
# 0  Random Forest       0.897859        0.930552     0.786462  0.852461
#
#    Test_ROC_AUC   Test_AP
# 0      0.958292  0.943403

# %%
confusion_matrix_graf(    
    # ваша обученная модель
    model=rfc,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='Random Forest'
)

# %%
roc_curves_graf(
    model=rfc,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='Random Forest'
)

# %%
precision_recall_curves_graf(
    model=rfc,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='Random Forest'
)

# %%
lr = LogisticRegression(random_state=21, max_iter=1000, solver='liblinear', n_jobs=12)

# %%
lr.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, n_jobs=12, random_state=21,
#                    solver='liblinear')

# %%
results_df = evaluate_model(
    model=lr,  # ваша обученная модель
    X_train=X_train_scaled,
    X_test=X_test_scaled, 
    y_train=y_train,
    y_test=y_test,
    model_name='Logistic Regression',
    results_df=results_df
)

# %%
results_df
# Out:
#                  Model  Test_Accuracy  Test_Precision  Test_Recall   Test_F1  \
# 0        Random Forest       0.897859        0.930552     0.786462  0.852461
# 1  Logistic Regression       0.772804        0.761968     0.573676  0.654550
#
#    Test_ROC_AUC   Test_AP
# 0      0.958292  0.943403
# 1      0.793777  0.757824

# %%
confusion_matrix_graf(    
    # ваша обученная модель
    model=lr,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='Logistic Regression'
)

# %%
roc_curves_graf(
    model=lr,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='Logistic Regression'
)

# %%
precision_recall_curves_graf(
    model=lr,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='Logistic Regression'
)

# %%
xgb = XGBClassifier(
    max_depth=6,
    learning_rate=0.1,
    n_estimators=1000,
    subsample=0.9,
    eval_metric='logloss',
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=21,
    n_jobs=12
)

# %%
param_distributions = {
    'max_depth': [4, 5, 6],           # было 5 значений
    'learning_rate': [0.05, 0.1],     # было 4 значения  
    'n_estimators': [100, 200],       # было 4 значения
    'subsample': [0.8, 0.9],  
    # 'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
}

# %%
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_distributions,
    n_iter=15, # Количество случайных комбинаций
    cv=2,      # Количество фолдов для кросс-валидации
    scoring='accuracy',
    n_jobs=-1, # Использовать все ядра процессора
    random_state=21,
    verbose=1
)

# %%
xgb.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=12,
#               num_parallel_tree=None, ...)

# %%
random_search.fit(X_train_scaled, y_train)
# Out:
# Fitting 2 folds for each of 15 candidates, totalling 30 fits
# RandomizedSearchCV(cv=2,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=0.8, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_const...
#                                            max_delta_step=None, max_depth=6,
#                                            max_leaves=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=1000, n_jobs=12,
#                                            num_parallel_tree=None, ...),
#                    n_iter=15, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.05, 0.1],
#                                         'max_depth': [4, 5, 6],
#                                         'n_estimators': [100, 200],
#                                         'subsample': [0.8, 0.9]},
#                    random_state=21, scoring='accuracy', verbose=1)

# %%
results_df = evaluate_model(
    model=xgb,  # ваша обученная модель
    X_train=X_train_scaled,
    X_test=X_test_scaled, 
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier',
    results_df=results_df
)

# %%
results_df = evaluate_model(
    model=random_search,  # ваша обученная модель
    X_train=X_train_scaled,
    X_test=X_test_scaled, 
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier_search',
    results_df=results_df
)

# %%
results_df
# Out:
#                   Model  Test_Accuracy  Test_Precision  Test_Recall   Test_F1  \
# 0         Random Forest       0.897859        0.930552     0.786462  0.852461
# 1   Logistic Regression       0.772804        0.761968     0.573676  0.654550
# 2         XGBClassifier       0.877440        0.899308     0.758243  0.822773
# 3  XGBClassifier_search       0.845168        0.863111     0.698045  0.771851
#
#    Test_ROC_AUC   Test_AP
# 0      0.958292  0.943403
# 1      0.793777  0.757824
# 2      0.943175  0.924534
# 3      0.912731  0.887565

# %%
confusion_matrix_graf(    
    # ваша обученная модель
    model=xgb,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier'
)

# %%
confusion_matrix_graf(    
    # ваша обученная модель
    model=random_search,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier_search'
)

# %%
roc_curves_graf(
    model=xgb,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier'
)

# %%
roc_curves_graf(
    model=random_search,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier_search'
)

# %%
precision_recall_curves_graf(
    model=xgb,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier'
)

# %%
precision_recall_curves_graf(
    model=random_search,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='XGBClassifier_search'
)

# %%
lgbm = LGBMClassifier(
        n_estimators=1000,
        learning_rate=0.1,
        max_depth=8,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=21
    )

# %%
lgbm.fit(X_train_scaled, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 132960, number of negative: 221408
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.142635 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17808
# [LightGBM] [Info] Number of data points in the train set: 354368, number of used features: 76
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.375203 -> initscore=-0.509959
# [LightGBM] [Info] Start training from score -0.509959
# LGBMClassifier(colsample_bytree=0.8, max_depth=8, n_estimators=1000,
#                random_state=21, subsample=0.8)

# %%
results_df = evaluate_model(
    model=lgbm,  # ваша обученная модель
    X_train=X_train_scaled,
    X_test=X_test_scaled, 
    y_train=y_train,
    y_test=y_test,
    model_name='LGBMClassifier',
    results_df=results_df
)

# %%
results_df.sort_values(by='Test_Precision', ascending=False)
# Out:
#                   Model  Test_Accuracy  Test_Precision  Test_Recall   Test_F1  \
# 0         Random Forest       0.897859        0.930552     0.786462  0.852461
# 2         XGBClassifier       0.877440        0.899308     0.758243  0.822773
# 4        LGBMClassifier       0.871277        0.893896     0.745397  0.812920
# 3  XGBClassifier_search       0.845168        0.863111     0.698045  0.771851
# 1   Logistic Regression       0.772804        0.761968     0.573676  0.654550
#
#    Test_ROC_AUC   Test_AP
# 0      0.958292  0.943403
# 2      0.943175  0.924534
# 4      0.936956  0.916654
# 3      0.912731  0.887565
# 1      0.793777  0.757824

# %%
confusion_matrix_graf(    
    # ваша обученная модель
    model=lgbm,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='LGBMClassifier'
)

# %%
roc_curves_graf(
    model=lgbm,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='LGBMClassifier'
)

# %%
precision_recall_curves_graf(
    model=lgbm,
    X_train=X_train_scaled, 
    X_test=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    model_name='LGBMClassifier'
)

# %%
for model in [rfc, xgb, lgbm]:
    feature_importance = pd.DataFrame({
        'feature': X_train_scaled.columns,
        'importance': model.feature_importances_
    }).sort_values('importance', ascending=False)

    print(model)
    print()
    print("Топ-10 признаков для класса 1")
    print(feature_importance.head(10))
    print('_______________________________________________________')
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=21)
#
# Топ-10 признаков для класса 1
#                                     feature  importance
# 23                              risk_factor    0.129161
# 31                          max_risk_factor    0.068033
# 30                          avg_risk_factor    0.062274
# 29  risk_factor_above_threshold_daily_count    0.052031
# 45               time_since_last_liquidated    0.023384
# 41                 time_since_first_deposit    0.023178
# 4                                wallet_age    0.016431
# 26              total_available_borrows_eth    0.015497
# 27          total_available_borrows_avg_eth    0.015389
# 46               liquidation_amount_sum_eth    0.014584
# _______________________________________________________
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=12,
#               num_parallel_tree=None, ...)
#
# Топ-10 признаков для класса 1
#                                     feature  importance
# 23                              risk_factor    0.306614
# 31                          max_risk_factor    0.048241
# 1                          borrow_timestamp    0.025321
# 41                 time_since_first_deposit    0.022026
# 29  risk_factor_above_threshold_daily_count    0.021987
# 45               time_since_last_liquidated    0.020057
# 27          total_available_borrows_avg_eth    0.017041
# 30                          avg_risk_factor    0.016294
# 3                         last_tx_timestamp    0.014978
# 0                       borrow_block_number    0.014163
# _______________________________________________________
# LGBMClassifier(colsample_bytree=0.8, max_depth=8, n_estimators=1000,
#                random_state=21, subsample=0.8)
#
# Топ-10 признаков для класса 1
#                      feature  importance
# 21              min_eth_ever        1106
# 31           max_risk_factor        1084
# 41  time_since_first_deposit         990
# 4                 wallet_age         889
# 2         first_tx_timestamp         864
# 9    avg_gas_paid_per_tx_eth         837
# 20              max_eth_ever         830
# 30           avg_risk_factor         809
# 7      net_incoming_tx_count         729
# 12  risky_first_tx_timestamp         688
# _______________________________________________________
